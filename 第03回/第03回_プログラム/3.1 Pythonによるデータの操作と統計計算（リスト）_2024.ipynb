# %% [markdown]
# <div style="text-align: right; font-weight: bold;">
# 東京工科大学コンピュータサイエンス学部<br>
# 福西広晃
# </div>

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size: 250%; color: black;">3.1 Pythonによるデータの操作と統計計算（リスト）</span>

# %% [markdown]
# ----

# %% [markdown]
# # データをまとめて管理する方法
# - 複数の値を1つの変数で管理しながら、個々の値（`要素`と呼ぶ）を取り出したり、場合によっては変更したりできると便利なことがある。そのためにPythonでは`リスト`、`タプル`、`辞書`、`集合`のデータ型が提供されている
# - **本講義では、特に重要な、`リスト`を学習する**
# <br><br>
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ----

# %% [markdown]
# # リストの書き方
# - `リスト`は、複数の値をまとめて扱う場合に使用
# - `リスト`は全体を`[]`で囲み、各要素は`カンマ`で区切る
# - `リスト`では`インデックス`(要素番号)を用いて、要素の追加や入れ替えなどが可能
# - `リスト`は型の値でも要素として格納することができ、リストの中にリストを格納することも可能である
# - `リスト`は、数値や文字列などの基本データ型と並んでPythonでは高頻度で使われるデータ型
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ----

# %% [markdown]
# # リストの作成

# %% [markdown]
# **5人のテスト結果が90点、85点、75点、95点、80点であったとする**

# %%
# リストをlistAの変数に代入
listA = [90, 85, 75, 95, 80]

# 表示
print(listA)

# %% [markdown]
# ## 練習
# 次の複数の値を纏めたリストを作成してみよう。リストの変数名を`lixtX`とする。
# - 112.3, 332.9, 573.8, 552.8, 123.8, 379.1, 332.6, 768.2, 249.8

# %% [markdown]
# ----

# %% [markdown]
# # リストの基本情報の取得

# %% [markdown]
# ## 要素数をカウントする
# 要素数のカウントには`len関数`を用いる
# ```Python
# len(リスト)
# ```

# %% [markdown]
# **listAの要素数**

# %%
list_num =  len(listA)

print("要素数：",list_num)

# %% [markdown]
# ## 要素の最大値、最小値を抽出
# - 最大値の抽出には、`max関数`を用いる
# ```Python
# max(リスト)
# ```
# - 最小値の抽出には、`min関数`を用いる
# ```Python
# min(リスト)
# ```

# %% [markdown]
# **listAの最大値と最小値**

# %%
list_max = max(listA)
list_min = min(listA)

print("最大値：", list_max)
print("最小値：", list_min)

# %% [markdown]
# ## 練習
# 以下にリストlistXに関して、以下の小問を解いてみよう。

# %%
listX = [112.3, 332.9, 573.8, 552.8, 123.8, 379.1, 332.6, 768.2, 249.8]

# %% [markdown]
# (1) listXの要素数を表示してみよう

# %% [markdown]
# (2) listXの最大値と最小値の差を計算して表示してみよう

# %% [markdown]
# ----

# %% [markdown]
# # リストの要素の操作

# %% [markdown]
# ## 要素の抽出
# - インデックス（要素番号）を指定
# ```
# リスト[インデックス]
# ```

# %%
print(listA[0])   # インデックス0を取り出して表示
print(listA[1])   # インデックス1を取り出して表示
print(listA[2])   # インデックス2を取り出して表示
print(listA[3])   # インデックス3を取り出して表示
print(listA[4])   # インデックス4を取り出して表示

# %% [markdown]
# ## 要素の置換
# - インデックス(要素番号)で置換前の要素を指定し、置換したい値を代入

# %%
# 変更前をリストを表示
print("置換前:", listA)

# インデックス0番を置換（最初の学生の点数は70点だった）
listA[0] = 70

# 変更後をリストを表示
print("置換後:", listA)

# %% [markdown]
# ## 要素の削除

# %% [markdown]
# ### インデックスによる要素の削除
# ```Python
# リスト.pop(削除する要素のインデックス)
# ```

# %%
# 削除前のリストを表示
listA = [90, 85, 75, 95, 80] # 5人の点数
print("削除前:", listA)

# インデックス(要素番号)0番目を削除
listA.pop(0)

# 削除後のリストを表示
print("削除後:", listA)

# %% [markdown]
# ### 特定の値の要素の削除
# ```
# リスト.remove(削除する要素)`
# ```
# - リストの中に該当する要素が見つからなかった場合はエラー(ValueError)が発生する
# - 削除される要素は「最初に該当したもの」のため、同じ値が2回以上出てくると最初に出る要素だけ削除される

# %%
# 削除前のリストを表示
listC = [90, 85, 75, 95, 85] # 5人の点数
print("削除前:", listC)

# 1つ目の85点を削除
listC.remove(85)

# 削除後のリストを表示
print("1回目削除後:", listC)

# 2つ目の85点を削除
listC.remove(85)

# 削除後のリストを表示
print("2回目削除後:", listC)

# %% [markdown]
# ## 練習
# 以下にリストlistXに関して、以下の小問を解いてみよう。

# %%
listX = [112.3, 332.9, 573.8, 552.8, 123.8, 379.1, 332.6, 768.2, 249.8]

# %% [markdown]
# (1) listXの左から4番目の要素を表示してみよう

# %% [markdown]
# (2) listXの左から6番目の要素を7.5に変更した後、listXを表示して確認してみよう。

# %% [markdown]
# (3) listXの左から2番目の要素を削除した後、listXを表示して確認してみよう。左から2番目のインデックスは1であることに注意しよう。

# %% [markdown]
# (4) listXの249.8の要素を削除した後、listXを表示して確認してみよう。

# %% [markdown]
# -----

# %% [markdown]
# # リストのサイズの操作

# %% [markdown]
# ## 複数のリストの結合
# `リストA = リストB + リストC`

# %% [markdown]
# **最初のテストの受験者5人の結果は、90点、85点、75点、95点、80点であったとする。その後、新たに4人がテストを受験して、70点, 80点, 75点, 90点であった。さらに、2人がテストを受験して85点、95点であった。**

# %%
listA = [90, 85, 75, 95, 80]
listB = [70, 80, 75, 90]
listC = [85, 95]

# listAとlistBを結合させてlistDを作成
listD = listA + listB

# リストを出力
print("1回目の結合：", listD)

# listDに対してlistCを結合させてlistDを拡張
listD = listD + listC     # listD += listC でも可

# リストを出力
print("2回目の結合：", listD)

# %% [markdown]
# ## 要素の追加
# `リスト.append(値)`

# %%
# 要素追加前
listA = [90, 80, 70, 60, 50]
print("要素追加前", listA)

# 要素追加
listA.append(40)
print("要素追加後", listA)

# %% [markdown]
# ## 練習
# 以下にリストlistXとlistYがある。

# %%
listX = [112.3, 332.9, 573.8, 552.8, 123.8, 379.1, 332.6, 768.2, 249.8]
listY = [44.8, 98.7]

# %% [markdown]
# (1) listXに対してlistYを結合してlistXを拡張した後、listXを表示してみよう

# %% [markdown]
# (2) (1)で得られたlistXに対して`121.5`の値を追加した後、listXを表示してみよう

# %% [markdown]
# (3) 結合後のlistXの要素数を表示してみよう

# %% [markdown]
# ----

# %% [markdown]
# # リストの要素の並び替え
# - `sorted関数`を用いる
#   - 昇順に並び替え（小→大）
#   ```Python
#   sorted(リスト)
#   ```
#   - 降順に並び替え（大→小）
#   ```Python
#   sorted(リスト,reverse=True)`
#   ```

# %% [markdown]
# ## 要素が数値の場合

# %%
listD = [90, 85, 75, 95, 80, 70, 80, 75, 90, 85]

# listDを昇順に並び替えてlistEに代入
listE = sorted(listD)
print("昇順に並び替え: ", listE)

# listDを降順に並び替えてlistFに代入
listF = sorted(listD, reverse=True)
print("降順に並び替え: ", listF)

# %% [markdown]
# ## 要素が文字列の場合(アルファベット順)

# %%
listG = ["dog", "cat", "tiger", "bird", "horse"]

listH = sorted(listG)
print("昇順に並び替え: ", listH)

listI = sorted(listG, reverse=True)
print("降順に並び替え: ", listI)

# %% [markdown]
# ## 練習
# 以下にリストlistXがある。listXの要素を降順に並び替えたlistYを作成して、listYを表示しよう

# %%
listX = [112.3, 332.9, 573.8, 552.8, 123.8, 379.1, 332.6, 768.2, 249.8]

# %% [markdown]
# ----

# %% [markdown]
# # for文によるリストの要素の操作
# ```Python
# for 要素を代入する変数 in リスト:
#     実行する処理
# ```
# 要素を1個ずつ変数に代入して繰り返す

# %% [markdown]
# **10人のテストの点数の合計値と平均値を計算**<br>

# %%
 # 10人のテストの点数を格納
listD = [90, 85, 75, 95, 80, 70, 80, 75, 90, 85]

total = 0               # 合計値の初期値を0とする
for i in listD:        # 要素を１個ずつ取り出して変数eleに代入
    total = total + i  # 要素を足す　

# 平均値 = 合計/要素数    
average = total / len(listD)  # 平均値をaverageという変数に代入

print("合計値", total)
print("平均値", average)

# %% [markdown]
# ## 練習
# 以下にリストlistXがある。listXの合計値と平均値を表示してみよう

# %%
listX = [112.3, 332.9, 573.8, 552.8, 123.8, 379.1, 332.6, 768.2, 249.8]

# %% [markdown]
# -----

# %% [markdown]
# # リスト内の要素の統計計算
# - 標準ライブラリの`statistics`を用いて、平均、中央値、最頻値、分散、標準偏差を算出できる
#   - ライブラリとは、よく使う機能・関数をまとめて、簡単に使えるようにしたもの
#   - ライブラリの中身のプログラムがブラックボックスであっても、入力と出力がわかっていれば簡単に実装し、実行することができる
#   - Pythonに便利な機能を持つライブラリが多数ある
# - 標準ライブラリを使う場合、import文で呼び出す
# ```Python
# import statistics
# statistics.mean(リスト)      # 平均値
# statistics.median(リスト)    # 中央値(要素を小さい方から大きい方に並べたときの中央の値)
# statistics.mode(リスト)      # 最頻値(最も出現頻度が高い値)
# statistics.pvariance(リスト) # 分散(データのばらつき)
# statistics.pstdev(リスト)    # 標準偏差(分散の平方根)
# ```
# ![image.png](attachment:image.png)

# %% [markdown]
# **10人のテストの点数の統計量を計算**

# %%
import statistics

# 10人の点数
listJ = [90, 85, 75, 95, 80, 70, 75, 90, 80, 75] 

mean = statistics.mean(listJ)
print("平均値: ",  mean)

median = statistics.median(listJ)
print("中央値: ", median)

mode = statistics.mode(listJ)
print("最頻値: ", mode)

pvariance = statistics.pvariance(listJ)
print("分散: ", pvariance) 

pstdev = statistics.pstdev(listJ)
print("標準偏差: ", pstdev)

# %% [markdown]
# ## 練習

# %% [markdown]
# 10人の身長をまとめたリストとしてhighAがある。平均値、中央値、最頻値、分散、標準偏差を求めてみよう。ただし、statisticsのライブラリをインポートして使用するものとする。

# %%
highA = [172, 175, 165, 168, 178, 172, 170, 166, 169, 164]

# %% [markdown]
# ----

# %% [markdown]
# # 総合練習（自習用）
# 5人の身長を測った結果、170cm、175cm、160cm、155cm、165cmであったとする

# %% [markdown]
# (1) 5人の身長の数値を要素とするリストをhigh1の変数名で作成して、要素数を表示しよう

# %% [markdown]
# (2) 左から4番目の人の身長に間違いがあったため150cmに変更して、リストを表示しよう

# %% [markdown]
# (3) 新たな5人の身長が180cm、155cm、160cm、165cm、170cmとする。
# 新たな5人の身長を要素とするリストをhigh2の変数名で作成してみよう。
# さらに、high1とhigh2を結合したリストをhigh3の変数名で作成し、表示しよう

# %% [markdown]
# (4) 10人の身長を降順で並び替えたリストをhigh4で作成し、表示しよう

# %% [markdown]
# (5) for文を利用し、10人の身長の平均値を計算して表示しよう。high4のリストを用いるものとする。

# %% [markdown]
# (6) 標準ライブラリのstatisticsを用いて、中央値、最頻値、分散、標準偏差を計算し表示しよう。high4のリストを用いるものとする。

# %% [markdown]
# (7) 身長158cm以下の人をhigh4から削除して表示しよう
